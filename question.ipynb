# %% [markdown]
# # 📄 Question: Data Analysis with Pandas and Matplotlib
# ## You have been provided with a dataset titanic.csv that contains information about passengers aboard the Titanic. The dataset includes the following columns:
# ## PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked
# # Task:
# ### Perform an exploratory data analysis (EDA) to answer the following:
# ### What percentage of passengers survived?
# ### How does survival rate vary by gender?
# ### What was the average age of survivors vs. non-survivors?
# ### Plot the number of passengers by class (Pclass).
# ### Visualize the age distribution of the passengers.
# ## Use Pandas for data analysis and Matplotlib or Seaborn for visualization. Provide clean and readable code with comments explaining each step.

# %% [markdown]
# ### 1. What percentage of passengers survived?

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('titanic_fake.csv')

# Show first 5 rows
df.head()

# Calculate survival percentage
survival_rate = df['Survived'].mean() * 100
print(f"Survival Rate: {survival_rate:.2f}%")
# Out:
# Survival Rate: 50.10%

# %% [markdown]
# ### 2. Survival Rate by Gender

# %%
# Group by Sex and calculate mean survival
gender_survival = df.groupby('Sex')['Survived'].mean() * 100
print("Survival Rate by Gender:\n", gender_survival)
# Out:
# Survival Rate by Gender:
#  Sex
# female    51.162791
# male      49.146110
# Name: Survived, dtype: float64

# %% [markdown]
# ### 3. Average age of survivors and non survivors

# %%
# Group by Survived and calculate average age
avg_age = df.groupby('Survived')['Age'].mean()
print("Average Age:\n", avg_age)
# Out:
# Average Age:
#  Survived
# 0    42.160120
# 1    40.097006
# Name: Age, dtype: float64

# %% [markdown]
# ### 4. Plot number of passengers by class

# %%
import matplotlib.pyplot as plt

# Count by Pclass
df['Pclass'].value_counts().sort_index().plot(kind='bar')
plt.title('Passenger Count by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 5. Visualize age distribution

# %%
import seaborn as sns

# Histogram of age
sns.histplot(df['Age'].dropna(), kde=True, bins=30, color='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.show()
